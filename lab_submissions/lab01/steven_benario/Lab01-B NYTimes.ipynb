# %%
import json
import requests

# %%
startyear = 2013
endyear = 2013
mykey = 'f24f8ba49940b4a690c352e10bd1e387:2:69647018'
searchterm = 'gaza'

# %%
teststring = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=%s&begin_date=%d0101&end_date=%d1231&api-key=%s' % (searchterm, startyear, startyear, mykey)

# %%
teststring
# Out:
# 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=gaza&begin_date=20130101&end_date=20131231&api-key=f24f8ba49940b4a690c352e10bd1e387:2:69647018'

# %%
requests.get(teststring).json()
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'52b5cf577988102b9524176c',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': None,
#     u'document_type': u'multimedia',
#     u'headline': {u'main': u'Mourning in Gaza', u'sub': u'Mourning in Gaza'},
#     u'keywords': [],
#     u'lead_paragraph': u'Mourners attend funeral processions for a Palestinian shot dead by Israeli forces along the Gaza border. Rough Cut (no reporter narration).',
#     u'multimedia': [],
#     u'news_desk': u'Multimedia/Photos',
#     u'print_page': None,
#     u'pub_date': u'2013-12-21T12:26:36Z',
#     u'section_name': u'Multimedia/Photos',
#     u'snippet': u'Mourners attend funeral processions for a Palestinian shot dead by Israeli forces along the Gaza border. Rough Cut (no reporter narration).',
#     u'source': u'Reuters',
#     u'subsection_name': None,
#     u'type_of_material': u'Video',
#     u'web_url': u'http://www.nytimes.com/video/2013/12/21/multimedia/100000002615747/mourning-in-gaza.html',
#     u'word_count': u'21'},
#    {u'_id': u'516f703afdc59276ee001311',
#     u'abstract': u'Photo of Palestinians waiting for food after United Nations reopens its Gaza food distribution centers. Photo (S)1',
#     u'blog': [],
#     u'byline': None,
#     u'document_type': u'article',
#     u'headline': {u'main': u'BACK IN LINE FOR FOOD IN GAZA'},
#     u'keywords': [{u'name': u'glocations', u'value': u'GAZA STRIP'},
#      {u'name': u'organizations', u'value': u'UNITED NATIONS'},
#      {u'name': u'subject', u'value': u'PALESTINIANS'}],
#     u'lead_paragraph': None,
#     u'multimedia': [],
#     u'news_desk': u'Foreign Desk',
#     u'print_page': u'8',
#     u'pub_date': u'2013-04-11T00:00:00Z',
#     u'section_name': None,
#     u'snippet': u'Photo of Palestinians waiting for food after United Nations reopens its Gaza food distribution centers. Photo (S)1',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Caption',
#     u'web_url': u'http://query.nytimes.com/gst/fullpage.html?res=9403E4DA133FF932A25757C0A9659D8B63',
#     u'word_count': None},
#    {u'_id': u'52bc9f327988107e40e20e07',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#      u'original': u'By THE ASSOCIATED PRESS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Israel Launches Airstrikes in Gaza',
#      u'print_headline': u'Israel Launches Airstrikes in Gaza'},
#     u'keywords': [],
#     u'lead_paragraph': u'The Israeli military says it has carried out airstrikes on two targets in the Gaza Strip in response to a pair of rocket attacks.',
#     u'multimedia': [],
#     u'news_desk': None,
#     u'print_page': None,
#     u'pub_date': u'2013-12-26T16:26:46Z',
#     u'section_name': u'World',
#     u'snippet': u'The Israeli military says it has carried out airstrikes on two targets in the Gaza Strip in response to a pair of rocket attacks.',
#     u'source': u'AP',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/aponline/2013/12/26/world/middleeast/ap-ml-israel-palestinians.html',
#     u'word_count': u'132'},
#    {u'_id': u'514d09aefdc5926e77001d36',
#     u'abstract': u'Editorial praises Pres Obama for brokering long-overdue reconciliation between Israel and Turkey; holds that normalization of diplomatic relations is essential step in restoring powerful cooperative force for stability in volatile region.',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'organization': u'THE EDITORIAL BOARD',
#      u'original': u'By THE EDITORIAL BOARD',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'kicker': u'Editorial',
#      u'main': u'Overdue Reconciliation',
#      u'print_headline': u'Overdue Reconciliation',
#      u'seo': u'Overdue Reconciliation'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Palestinians'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Israel'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'Free Gaza Movement'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Editorials'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Turkey'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'International Relations'}],
#     u'lead_paragraph': u'At President Obama\u2019s urging, Israel and Turkey have chosen a wiser course and restored diplomatic relations.',
#     u'multimedia': [],
#     u'news_desk': u'Editorial',
#     u'print_page': u'16',
#     u'pub_date': u'2013-03-23T00:00:00Z',
#     u'section_name': u'Opinion',
#     u'snippet': u'At President Obama\u2019s urging, Israel and Turkey have chosen a wiser course and restored diplomatic relations.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Editorial',
#     u'web_url': u'http://www.nytimes.com/2013/03/23/opinion/overdue-reconciliation.html',
#     u'word_count': u'311'},
#    {u'_id': u'513e03ddcf28d04ae0001796',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': [],
#     u'document_type': u'multimedia',
#     u'headline': {u'main': u'Mass Rally for Fatah in Gaza'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'3',
#       u'value': u'Fatah, Al'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Gaza Strip'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Palestinians'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Demonstrations, Protests, and Riots'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'2',
#       u'value': u'Hamas'}],
#     u'lead_paragraph': u'Tens of thousands of supporters of the Palestinian faction Fatah gathered in the Gaza Strip,',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 393,
#       u'legacy': {u'xlarge': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-articleLarge.jpg',
#        u'xlargeheight': u'393',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2013/01/04/world/middleeast/20121204_gaza_337-slide-FM92/20121204_gaza_337-slide-FM92-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'World / Middle East',
#     u'print_page': None,
#     u'pub_date': u'2013-01-04T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'Tens of thousands of supporters of the Palestinian faction Fatah gathered in the Gaza Strip,',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Slideshow',
#     u'web_url': u'http://www.nytimes.com/slideshow/2013/01/04/world/middleeast/20121204_gaza_337.html',
#     u'word_count': u'15'},
#    {u'_id': u'52a62ee67988102714a6a537',
#     u'abstract': u'Israel has agreed to restart the transfer of construction materials to the Gaza Strip after eight-week hiatus; country is under pressure from the United Nations amid a mounting economic and humanitarian crisis in Gaza.',
#     u'blog': [],
#     u'byline': {u'contributor': u'Fares Akram contributed reporting from Gaza.',
#      u'original': u'By JODI RUDOREN',
#      u'person': [{u'firstname': u'Jodi',
#        u'lastname': u'RUDOREN',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Israel to Allow Building Materials Into Gaza',
#      u'print_headline': u'Israel to Allow Building Materials Into Gaza'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'4',
#       u'value': u'Gaza Strip'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'2',
#       u'value': u'Hamas'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'5',
#       u'value': u'Israel'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Palestinians'},
#      {u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'United Nations'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'3',
#       u'value': u'Palestinian Authority'}],
#     u'lead_paragraph': u'After an eight-week hiatus, construction materials will be allowed in again starting Tuesday, but only for United Nations projects.',
#     u'multimedia': [],
#     u'news_desk': u'Foreign',
#     u'print_page': u'10',
#     u'pub_date': u'2013-12-10T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'After an eight-week hiatus, construction materials will be allowed in again starting Tuesday, but only for United Nations projects.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/12/10/world/middleeast/israel-building-materials-gaza.html',
#     u'word_count': u'672'},
#    {u'_id': u'515bf6dcfdc59278db00d3be',
#     u'abstract': u"Israeli-Palestinian tensions rise sharply with resumption of clashes at Gaza border as Palestinian prisoners in Israeli jails declare three-day hunger strike to protest fellow inmate's death, saying Israel is responsible.",
#     u'blog': [],
#     u'byline': {u'contributor': u'Fares Akram contributed reporting from Gaza.',
#      u'original': u'By ISABEL KERSHNER',
#      u'person': [{u'firstname': u'Isabel',
#        u'lastname': u'KERSHNER',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Tensions Rise as Israel and Gaza Swap Strikes',
#      u'print_headline': u'Tensions Rise As Israel And Gaza Swap Strikes',
#      u'seo': u'Clashes Resume Across Israel-Gaza Border'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Israel'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Palestinians'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'3',
#       u'value': u'Gaza Strip'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Hunger Strikes'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'Hamas'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Prisons and Prisoners'}],
#     u'lead_paragraph': u'Israel launched an air attack in response to rockets fired from Gaza as Palestinian prisoners declared a hunger strike.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2013/04/04/world/ISRAEL/ISRAEL-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2013/04/04/world/ISRAEL/ISRAEL-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2013/04/04/world/ISRAEL/ISRAEL-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2013/04/04/world/ISRAEL/ISRAEL-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2013/04/04/world/ISRAEL/ISRAEL-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2013/04/04/world/ISRAEL/ISRAEL-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'8',
#     u'pub_date': u'2013-04-04T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'Israel launched an air attack in response to rockets fired from Gaza as Palestinian prisoners declared a hunger strike.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/04/04/world/middleeast/israel-palestinians-gaza.html',
#     u'word_count': u'766'},
#    {u'_id': u'52b9a9ae7988100ef6dd0cbd',
#     u'abstract': u'Israeli laborer repairing security fence along the border with Gaza is fatally shot by a Palestinian sniper and a Palestinian toddler is killed when shell lands in front of her home in a refugee camp; deaths are latest in growing wave of Israeli-Palestinian violence that is accompanying difficult, American-brokered peace talks now underway.',
#     u'blog': [],
#     u'byline': {u'contributor': u'Fares Akram contributed reporting from Gaza.',
#      u'original': u'By ISABEL KERSHNER',
#      u'person': [{u'firstname': u'Isabel',
#        u'lastname': u'KERSHNER',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Killing and Retaliation at Gaza-Israel Border Continue Violent Cycle',
#      u'print_headline': u'Killing and Retaliation at Gaza-Israel Border Continue Violent Cycle'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Civilian Casualties'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'9',
#       u'value': u'Latif, Salah Abu'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'7',
#       u'value': u'Israel'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Defense and Military Forces'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Deaths (Fatalities)'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'8',
#       u'value': u'Sbeikha, Hala Abu'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Gaza Strip'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Terrorism'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Palestinians'}],
#     u'lead_paragraph': u'The deaths of an Israeli laborer and a Palestinian toddler were the latest in a growing wave of Israeli-Palestinian violence.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 300,
#       u'legacy': {u'xlarge': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-articleLarge.jpg',
#        u'xlargeheight': u'300',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2013/12/25/world/middleeast/25GAZA-alt_SPAN/25GAZA-alt_SPAN-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'12',
#     u'pub_date': u'2013-12-25T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'The deaths of an Israeli laborer and a Palestinian toddler were the latest in a growing wave of Israeli-Palestinian violence.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/12/25/world/middleeast/israeli-palestinian-violence.html',
#     u'word_count': u'888'},
#    {u'_id': u'52b7667f798810193ff56da7',
#     u'abstract': u'Passengers flee bus in Bat Yam near Tel Aviv, Israel, minutes before bomb explodes aboard it; police credit alertness of driver and passengers, who noticed large unclaimed bag on seat.',
#     u'blog': [],
#     u'byline': {u'contributor': u'Fares Akram contributed reporting from Gaza.',
#      u'original': u'By ISABEL KERSHNER',
#      u'person': [{u'firstname': u'Isabel',
#        u'lastname': u'KERSHNER',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Passengers on Bus Near Tel Aviv Flee Just Before a Bomb Explodes',
#      u'print_headline': u'Passengers on Bus Near Tel Aviv Flee Just Before a Bomb Explodes'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Terrorism'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Bombs and Explosives'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Palestinians'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Israel'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Yoger, Michael'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Buses'}],
#     u'lead_paragraph': u'Alert passengers and a bus driver are credited with saving the lives of those aboard the bus.',
#     u'multimedia': [],
#     u'news_desk': u'Foreign',
#     u'print_page': u'12',
#     u'pub_date': u'2013-12-23T00:00:00Z',
#     u'section_name': u'World',
#     u'snippet': u'Alert passengers and a bus driver are credited with saving the lives of those aboard the bus.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Middle East',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/12/23/world/middleeast/bus-in-israel-is-evacuated-before-a-bomb-goes-off.html',
#     u'word_count': u'489'},
#    {u'_id': u'517b8cbdfdc5920bc400163d',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#      u'original': u'By THE ASSOCIATED PRESS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Prominent Muslim Cleric to Visit Gaza',
#      u'print_headline': u'Prominent Muslim Cleric to Visit Gaza'},
#     u'keywords': [],
#     u'lead_paragraph': u"The head of Gaza's Islamic affairs ministry says the prominent Muslim scholar Yusuf al-Qaradawi will visit the Hamas-ruled territory in May.",
#     u'multimedia': [],
#     u'news_desk': u'None',
#     u'print_page': None,
#     u'pub_date': u'2013-04-27T04:27:49Z',
#     u'section_name': u'World',
#     u'snippet': u"The head of Gaza's Islamic affairs ministry says the prominent Muslim scholar Yusuf al-Qaradawi will visit the Hamas-ruled territory in May.",
#     u'source': u'AP',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/aponline/2013/04/27/world/middleeast/ap-ml-palestinians-gaza-cleric.html',
#     u'word_count': u'136'}],
#   u'meta': {u'hits': 974, u'offset': 0, u'time': 144}},
#  u'status': u'OK'}

# %%
r = requests.get(teststring)
myjson = r.json()

# %%
myjson['response']['meta']['hits']
# Out:
# 974

# %%
def querybyyear(term, year):
	#input: query term, year
	#output: number of results

	#this function calls the NYT api to get how many responses there are in a year
	#r = requests.get('http://api.nytimes.com/svc/search/v2/articlesearch.json?q=gaza&begin_date=20130101&end_date=20131231&api-key=f24f8ba49940b4a690c352e10bd1e387:2:69647018')
	mykey = 'f24f8ba49940b4a690c352e10bd1e387:2:69647018'

	requestString = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=%s&begin_date=%d0101&end_date=%d1231&api-key=%s' % (term, year, year, mykey)


	myResponse = requests.get(requestString).json()
	numHits = myResponse['response']['meta']['hits']

	return numHits

# %%
querybyyear('gaza', 2014)
# Out:
# 2169

# %%
def generateListing(term):
	#This function generates the (DATASTRUCT) that has year, and # responses, for all years from 
	#1900 to 2013
	startyear = 1980
	years = range(startyear,2014)   #note that range includes bottom number, and excludes top number

	myResults = []
	for i in range(len(years)):
		myResults.append(querybyyear(term, years[i]))

	#we have now looped through and done a query for all years in the list.
	# currently we have years -- a list from startyear to 2013
	# and myResults, a list of the results for each year, with corresponding indexes

	return(years, myResults)

# %%
(myyears, output) = generateListing('gaza')

# %%
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# <type 'list'>
# 14
# [391, 589, 755, 669, 727, 697, 731, 571, 464, 918, 636, 633, 1143, 974]
# <type 'list'>
# 14

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(myyears, output)
plt.xlabel('year')
plt.ylabel('number of articles')
plt.title('Number of Articles by year')
plt.show()
