# %%
import sklearn 
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(open('airline.csv'))
print df.head()
# Out:
#    Unnamed: 0  airline  year     cost    output    fuel      load
# 0           1        1     1  1140640  0.952757  106650  0.534487
# 1           2        1     2  1215690  0.986757  110307  0.532328
# 2           3        1     3  1309570  1.091980  110574  0.547736
# 3           4        1     4  1511530  1.175780  121974  0.540846
# 4           5        1     5  1676730  1.160170  196606  0.591167

# %%
for i in airline.columns.values:
    print i
# Out:
# Unnamed: 0
# airline
# year
# cost
# output
# fuel
# load

# %%
X = df[['output', 'fuel', 'year']]
y = df['cost']
print X.shape
# Out:
# (90, 3)

# %%
y.describe()
# Out:
# count         90.000000
# mean     1122523.833333
# std      1192074.703967
# min        68978.000000
# 25%       292046.000000
# 50%       637001.000000
# 75%      1345967.500000
# max      4748320.000000
# dtype: float64

# %%
X.describe()
# Out:
#           output            fuel       year
# count  90.000000       90.000000  90.000000
# mean    0.544995   471683.011111   8.000000
# std     0.533586   329502.907713   4.344698
# min     0.037682   103795.000000   1.000000
# 25%     0.142128   129847.500000   4.000000
# 50%     0.305028   357433.500000   8.000000
# 75%     0.945278   849839.750000  12.000000
# max     1.936460  1015610.000000  15.000000

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
#import function to test train split
from sklearn.cross_validation import train_test_split

# %%
#create different training sets from X and y
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# create an instance of the LinearRegression class
regressor = LinearRegression()

# %%
# Fit the training data
print regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
# Evaluate the performance of the regressor on the test set.
regressor.score(X_test, y_test)
# Out:
# 0.91225165971308209

# %%
# Predict the value of the response variable with the test set
predictions = regressor.predict(X_test)

# %%
# Compare each prediction to the true cost
for i, p in enumerate(predictions):
    print p, y_test[i]
# Out:
# 275139.533391 274024
# 1238007.47392 999294
# 1111309.34757 1193680
# 947809.755988 610257
# 656037.470998 676771
# 1071201.84312 783799
# -254230.99548 91361
# 175287.951632 210212
# 4051336.75284 4282880
# 2387630.07312 2022890
# -231843.524036 95428
# 1505396.70598 1198930
# 1262322.96476 1303390
# 408490.829948 532590
# -34424.4426672 247506
# -254099.443236 74904
# 908970.949026 506969
# 284630.99001 342056
# 1794686.49655 1309570
# 952581.011224 880438
# 1710415.21336 1501350
# 898653.827746 581447
# 854951.982287 669331

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.cm as cm

# %%
df
# Out:
#     Unnamed: 0  airline  year     cost    output     fuel      load
# 0            1        1     1  1140640  0.952757   106650  0.534487
# 1            2        1     2  1215690  0.986757   110307  0.532328
# 2            3        1     3  1309570  1.091980   110574  0.547736
# 3            4        1     4  1511530  1.175780   121974  0.540846
# 4            5        1     5  1676730  1.160170   196606  0.591167
# 5            6        1     6  1823740  1.173760   265609  0.575417
# 6            7        1     7  2022890  1.290510   263451  0.594495
# 7            8        1     8  2314760  1.390670   316411  0.597409
# 8            9        1     9  2639160  1.612730   384110  0.638522
# 9           10        1    10  3247620  1.825440   569251  0.676287
# 10          11        1    11  3787750  1.546040   871636  0.605735
# 11          12        1    12  3867750  1.527900   997239  0.614360
# 12          13        1    13  3996020  1.660200   938002  0.633366
# ...

# %%
#Make a scatter plot using the explanatory and responsive variables
X2 = df['fuel']
y = df['cost'] 

plt.scatter(X2,y)
print plt.scatter
    
plt.title('Airline')
print plt.title
# TODO add labels for the x and y axes
plt.xlabel('Fuel Cost')
plt.ylabel('Airline Cost')

plt.show()
# Out:
# <function scatter at 0x1091060c8>
# <function title at 0x1091021b8>

# %%
X2.plot(colormap='cubehelix')
y.plot(colormap='cubehelix')
